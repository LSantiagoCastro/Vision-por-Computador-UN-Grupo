# %%
import numpy as np
from cv2 import imread
import matplotlib.pyplot as plt

# %%
FILEID = "12ba7E_rxvkKXSElYQeOrZPBxpWQyv2QO"
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id='$FILEID -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id="$FILEID -O Numpy_wolf_crop.jpeg && rm -rf /tmp/cookies.txt > /dev/null
# Out:
# --2022-04-26 19:12:03--  https://docs.google.com/uc?export=download&confirm=&id=12ba7E_rxvkKXSElYQeOrZPBxpWQyv2QO
# Resolving docs.google.com (docs.google.com)... 74.125.31.102, 74.125.31.113, 74.125.31.138, ...
# Connecting to docs.google.com (docs.google.com)|74.125.31.102|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-14-60-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/ki4sg5av873t1ssr7tmilb40oi5rb62i/1651000275000/09711457892284675029/*/12ba7E_rxvkKXSElYQeOrZPBxpWQyv2QO?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2022-04-26 19:12:03--  https://doc-14-60-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/ki4sg5av873t1ssr7tmilb40oi5rb62i/1651000275000/09711457892284675029/*/12ba7E_rxvkKXSElYQeOrZPBxpWQyv2QO?e=download
# Resolving doc-14-60-docs.googleusercontent.com (doc-14-60-docs.googleusercontent.com)... 172.253.123.132, 2607:f8b0:400c:c16::84
# Connecting to doc-14-60-docs.googleusercontent.com (doc-14-60-docs.googleusercontent.com)|172.253.123.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 334669 (327K) [image/jpeg]
# Saving to: ‘Numpy_wolf_crop.jpeg’
#
# Numpy_wolf_crop.jpe 100%[===================>] 326.83K  --.-KB/s    in 0.003s
#
# 2022-04-26 19:12:04 (120 MB/s) - ‘Numpy_wolf_crop.jpeg’ saved [334669/334669]

# %%
img = imread('./Numpy_wolf_crop.jpeg', 0) #Read image in grayscale and return in a numpy array
print('Original Image shape = ',img.shape)
print('Maximun pixel value (white) = ',img.max())
fig = plt.figure(figsize=(10,10))
plt.imshow(img, cmap='gray')
plt.colorbar(orientation='horizontal', ticks=[img.min(), img.max()])
# Out:
# Original Image shape =  (1212, 2416)
# Maximun pixel value (white) =  255

# %%
class ModificarImagen: #Crear Clase
  """ 
  Cortar espacios en blanco de la imagen
  """
  def __init__(self): #CONTRUCTOR 
   pass
 
  def Cut(): #METODOS...
    img= imread('./Numpy_wolf_crop.jpeg', 0)
    v=img[110:1100,172:2229]
    return v 
  def Nimg():
    v=img[110:1100,172:2229]
    fig = plt.figure(figsize=(10,10))
    plt.imshow(v, cmap='gray')
    plt.colorbar(orientation='horizontal', ticks=[img.min(), img.max()])

# %%
cambiar = ModificarImagen

# %%
x=cambiar.Cut()

# %%
x
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
y=cambiar.Nimg()
