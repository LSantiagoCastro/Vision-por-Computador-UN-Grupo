# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
imagenOriginal = 'imagen.jpg'

Imagen = cv2.imread(imagenOriginal)
ImgRgb = cv2.cvtColor(Imagen, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(ImgRgb)

# %%
rec = Imagen[ 200:300 , 300:400 ]

rgb = cv2.cvtColor(rec, cv2.COLOR_BGR2RGB)


plt.imshow(rgb)

# %%
C1 = rec[:,:,0]
C2 = rec[:,:,1]
C3 = rec[:,:,2]

fig = plt.figure(figsize=(20,4))

ax_1 =fig.add_subplot(141)
plt.imshow(rec, cmap='gray')

ax_2 = fig.add_subplot(142)
plt.imshow(C1, cmap = 'gray',)

ax_3=fig.add_subplot(143)
plt.imshow(C2, cmap='gray',)

ax_4=fig.add_subplot(144)
plt.imshow(C3, cmap='gray',)

fig.suptitle("RGB")
plt.show()

# %%
class Crear_imagen(): #Crear Clase
  """ 
  Clase para crear imagenes en los diferentes canales RGB
  """
  def __init__(self, M): 
    self.M = M 
    x,y  = np.shape(self.M)
    self.x= x
    self.y = y

  def blue(self):
    
    return (plt.imshow(M, cmap = 'Blues', vmin = 0, vmax = 255, extent = (0,self.x, 0,self.y)),
    plt.colorbar(),    
    plt.title('Image blue'),
    plt.ylabel('Y'),
    plt.xlabel('X'))

  def green(self): 
        
    return (plt.imshow(M, cmap = 'Greens', vmin = 0, vmax = 255, extent = (0,self.x, 0,self.y)),
    plt.colorbar(),
    plt.title('Image green'),
    plt.ylabel('Y'),
    plt.xlabel('X'))

  def red(self): 
    
    return (plt.imshow(M, cmap = 'Reds', vmin = 0, vmax = 255, extent = (0,self.x, 0,self.y)),
    plt.colorbar(),
    plt.title('Image red'),
    plt.ylabel('Y'),
    plt.xlabel('X'))

  def gray(self): 
    
    return (plt.imshow(M, cmap = 'Greys', vmin = 0, vmax = 255, extent = (0,self.x, 0,self.y)),
    plt.colorbar(),
    plt.title('Imagen gray'),
    plt.ylabel('Y'),
    plt.xlabel('X')
    )

# %%
M = np.random.randint(0,255, (1000,1000))

# %%
im = Crear_imagen(M)

# %%
blue = im.blue
green = im.green
red = im.red 
gray = im.gray

# %%
fig = plt.figure(figsize=(20,4))

ax_1 =fig.add_subplot(141)
blue()

ax_2 = fig.add_subplot(142)
green()

ax_3=fig.add_subplot(143)
red()

ax_4=fig.add_subplot(144)
gray()

#fig.suptitle("RGB")
#plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7f70c0bec850>,
#  <matplotlib.colorbar.Colorbar at 0x7f70c0bec790>,
#  Text(0.5, 1.0, 'Imagen gray'),
#  Text(0, 0.5, 'Y'),
#  Text(0.5, 0, 'X'))
