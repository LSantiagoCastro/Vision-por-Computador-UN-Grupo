# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

#https://drive.google.com/file/d/1oSq0t0SgIDGwJzhuZ368tDGwkTbEHJzT/view?usp=sharing
FILEID = "1oSq0t0SgIDGwJzhuZ368tDGwkTbEHJzT"
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id='$FILEID -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id="$FILEID -O imagen.jpg && rm -rf /tmp/cookies.txt
# Out:
# --2022-05-04 12:38:40--  https://docs.google.com/uc?export=download&confirm=&id=1oSq0t0SgIDGwJzhuZ368tDGwkTbEHJzT
# Resolving docs.google.com (docs.google.com)... 108.177.111.100, 108.177.111.102, 108.177.111.101, ...
# Connecting to docs.google.com (docs.google.com)|108.177.111.100|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-00-7c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/k9qltec143l8ifh1lir70fsf5kv2edqs/1651667850000/02377704674902172911/*/1oSq0t0SgIDGwJzhuZ368tDGwkTbEHJzT?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2022-05-04 12:38:40--  https://doc-00-7c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/k9qltec143l8ifh1lir70fsf5kv2edqs/1651667850000/02377704674902172911/*/1oSq0t0SgIDGwJzhuZ368tDGwkTbEHJzT?e=download
# Resolving doc-00-7c-docs.googleusercontent.com (doc-00-7c-docs.googleusercontent.com)... 172.253.114.132, 2607:f8b0:4001:c22::84
# Connecting to doc-00-7c-docs.googleusercontent.com (doc-00-7c-docs.googleusercontent.com)|172.253.114.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 110589 (108K) [image/jpeg]
# Saving to: ‘imagen.jpg’
#
# imagen.jpg          100%[===================>] 108.00K  --.-KB/s    in 0.001s
#
# 2022-05-04 12:38:41 (79.4 MB/s) - ‘imagen.jpg’ saved [110589/110589]

# %%
path_image = 'imagen.jpg'

img = cv2.imread(path_image)
imgrgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(imgrgb)

# %%
rec = img[0:300, 600:1000 ]

rgb = cv2.cvtColor(rec, cv2.COLOR_BGR2RGB)


plt.imshow(rgb)

# %%
C1 = rec[:,:,0]
C2 = rec[:,:,1]
C3 = rec[:,:,2]

fig = plt.figure(figsize=(20,4))

ax_1 =fig.add_subplot(141)
plt.imshow(rec, cmap='gray')

ax_2 = fig.add_subplot(142)
plt.imshow(C1, cmap = 'gray',)

ax_3=fig.add_subplot(143)
plt.imshow(C2, cmap='gray',)

ax_4=fig.add_subplot(144)
plt.imshow(C3, cmap='gray',)

fig.suptitle("RGB")
plt.show()

# %% [markdown]
# #Crear imagen azul, verde, roja, blanca, negra.

# %%
class Crear_imagen(): #Crear Clase
  """ 
 Clase con metodos para crear imagenes de color azul, verde, rojo, blanca, negra
  """
  def __init__(self, M): 
    self.M = M 
    x,y  = np.shape(self.M)
    self.x= x
    self.y = y

  def blue(self): #METODOS..
    
    return (plt.imshow(M, cmap = 'Blues', vmin = 0, vmax = 255, extent = (0,self.x, 0,self.y)),
    plt.colorbar(),    
    plt.title('Image blue'),
    plt.ylabel('Y'),
    plt.xlabel('X'))

  def green(self): #METODOS..
        
    return (plt.imshow(M, cmap = 'Greens', vmin = 0, vmax = 255, extent = (0,self.x, 0,self.y)),
    plt.colorbar(),
    plt.title('Image green'),
    plt.ylabel('Y'),
    plt.xlabel('X'))

  def red(self): #METODOS..
    
    return (plt.imshow(M, cmap = 'Reds', vmin = 0, vmax = 255, extent = (0,self.x, 0,self.y)),
    plt.colorbar(),
    plt.title('Image red'),
    plt.ylabel('Y'),
    plt.xlabel('X'))

  def gray(self): #METODOS..
    
    return (plt.imshow(M, cmap = 'Greys', vmin = 0, vmax = 255, extent = (0,self.x, 0,self.y)),
    plt.colorbar(),
    plt.title('Imagen gray'),
    plt.ylabel('Y'),
    plt.xlabel('X')
    )

# %%
M = np.random.randint(0,255, (1000,1000))

# %%
im = Crear_imagen(M)

# %%
blue = im.blue
green = im.green
red = im.red 
gray = im.gray

# %%
fig = plt.figure(figsize=(20,4))

ax_1 =fig.add_subplot(141)
blue()

ax_2 = fig.add_subplot(142)
green()

ax_3=fig.add_subplot(143)
red()

ax_4=fig.add_subplot(144)
gray()

#fig.suptitle("RGB")
#plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7f00e6d86790>,
#  <matplotlib.colorbar.Colorbar at 0x7f00e6d866d0>,
#  Text(0.5, 1.0, 'Imagen gray'),
#  Text(0, 0.5, 'Y'),
#  Text(0.5, 0, 'X'))
