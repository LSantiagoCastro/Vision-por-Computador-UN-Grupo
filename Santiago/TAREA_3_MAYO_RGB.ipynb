# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

#https://drive.google.com/file/d/1oSq0t0SgIDGwJzhuZ368tDGwkTbEHJzT/view?usp=sharing
FILEID = "1oSq0t0SgIDGwJzhuZ368tDGwkTbEHJzT"
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id='$FILEID -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id="$FILEID -O imagen.jpg && rm -rf /tmp/cookies.txt
# Out:
# --2022-05-15 23:06:30--  https://docs.google.com/uc?export=download&confirm=&id=1oSq0t0SgIDGwJzhuZ368tDGwkTbEHJzT
# Resolving docs.google.com (docs.google.com)... 74.125.142.101, 74.125.142.138, 74.125.142.139, ...
# Connecting to docs.google.com (docs.google.com)|74.125.142.101|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-00-7c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/5ahprvbpvkl7qtrhr6jr4hbtrf17n5nt/1652655975000/02377704674902172911/*/1oSq0t0SgIDGwJzhuZ368tDGwkTbEHJzT?e=download [following]
# ...
# --2022-05-15 23:06:30--  https://doc-00-7c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/5ahprvbpvkl7qtrhr6jr4hbtrf17n5nt/1652655975000/02377704674902172911/*/1oSq0t0SgIDGwJzhuZ368tDGwkTbEHJzT?e=download
# Resolving doc-00-7c-docs.googleusercontent.com (doc-00-7c-docs.googleusercontent.com)... 74.125.197.132, 2607:f8b0:400e:c03::84
# ...

# %%
path_image = 'imagen.jpg'

img = cv2.imread(path_image)
imgrgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(imgrgb)

# %%
rec = img[0:300, 600:1000 ]

rgb = cv2.cvtColor(rec, cv2.COLOR_BGR2RGB)


plt.imshow(rgb)

# %%
C1 = rec[:,:,0]
C2 = rec[:,:,1]
C3 = rec[:,:,2]

fig = plt.figure(figsize=(20,4))

ax_1 =fig.add_subplot(141)
plt.imshow(rec, cmap='gray')

ax_2 = fig.add_subplot(142)
plt.imshow(C1, cmap = 'gray',)

ax_3=fig.add_subplot(143)
plt.imshow(C2, cmap='gray',)

ax_4=fig.add_subplot(144)
plt.imshow(C3, cmap='gray',)

fig.suptitle("RGB")
plt.show()

# %% [markdown]
# #Crear imagen azul, verde, roja, blanca, negra.

# %%
h = 1000
w = 1000
c = 3
max = 255

imagen = np.zeros([h,w,c], dtype = int)

# %%
imagen.shape
# Out:
# (1000, 1000, 3)

# %%
white = imagen + [max, max, max]

# %%
bk = imagen + [0, 0, 0]
bk = bk.astype(int)

r = imagen + [max, 0, 0]
r = r.astype(int)

g = imagen + [0, max, 0]
g = g.astype(int)

b = imagen + [0, 0, max]
b= b.astype(int)

gray = imagen + [100, 100, 100]
rg = r + g
gb = g + b
rb = r+ b
w = r+g+b

# %%
fig = plt.figure(figsize= (15,15) )
#fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(6,6))



ax_1 =fig.add_subplot(331)
plt.title('White = Red + Green + Blue')
plt.imshow(white)

ax_2 =fig.add_subplot(332)
plt.title('Black')
plt.imshow(bk)


ax_3 =fig.add_subplot(333)
plt.title('Gray')
plt.imshow(gray, cmap = 'Greys')


ax_4 =fig.add_subplot(334)
plt.title('Red')
plt.imshow(r)


ax_5 = fig.add_subplot(335)
plt.imshow(g)
plt.title('Green')

ax_6=fig.add_subplot(336)
plt.imshow(b)
plt.title('Blue')

ax_7 = fig.add_subplot(337)
plt.imshow(rg)
plt.title('Red + Green')

ax_8 = fig.add_subplot(338)
plt.imshow(rb)
plt.title('Red + blue')

ax_9 = fig.add_subplot(339)
plt.imshow(gb)
plt.title('Green + Blue')
# Out:
# Text(0.5, 1.0, 'Green + Blue')
